# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
df = spark.read.format('parquet').load('s3://raw/orders/')

# %%
df.write.format('delta').saveAsTable('prod.mart.orders_out')

# %%
print('done')
